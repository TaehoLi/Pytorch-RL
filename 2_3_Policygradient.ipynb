# %%
# 구현에 사용할 패키지 임포트하기
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta를 행동정책 pi로 변환(소프트맥스 함수 사용)하는 함수


def softmax_convert_into_pi_from_theta(theta):
    '''비율 계산에 소프트맥스 함수 사용'''

    beta = 1.0
    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # theta를 exp(theta)로 변환

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # 단순 비율을 계산하는 코드

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmax로 계산하는 코드

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# %%
# 초기 정책 pi_0을 계산
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 행동 a를 취한 후의 상태 s를 구하는 함수

def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    # pi[s,:]의 확률을 따라, direction값이 선택된다
    next_direction = np.random.choice(direction, p=pi[s, :])

    if next_direction == "up":
        action = 0
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return [action, s_next]

# %%
# 미로를 빠져나오는 함수, 상태와 행동의 히스토리를 출력한다


def goal_maze_ret_s_a(pi):
    s = 0  # 시작 지점
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 현재 상태(마지막이므로 인덱스가 -1)를 히스토리에 추가

        s_a_history.append([next_s, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다.

        if next_s == 8:  # 목표 지점에 이르면 종료
            break
        else:
            s = next_s

    return s_a_history

# %%
# 초기 정책으로 미로를 빠져나오기
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")
# Out:
# [[0, 2], [3, 2], [6, 0], [3, 1], [4, 2], [7, 0], [4, 3], [3, 2], [6, 0], [3, 1], [4, 3], [3, 2], [6, 0], [3, 1], [4, 3], [3, 0], [0, 1], [1, 1], [2, 3], [1, 3], [0, 1], [1, 1], [2, 3], [1, 1], [2, 3], [1, 3], [0, 2], [3, 0], [0, 1], [1, 1], [2, 2], [5, 0], [2, 2], [5, 0], [2, 2], [5, 0], [2, 3], [1, 3], [0, 2], [3, 0], [0, 2], [3, 1], [4, 3], [3, 1], [4, 3], [3, 2], [6, 0], [3, 0], [0, 1], [1, 3], [0, 2], [3, 2], [6, 0], [3, 1], [4, 3], [3, 0], [0, 2], [3, 0], [0, 1], [1, 3], [0, 2], [3, 1], [4, 2], [7, 0], [4, 3], [3, 0], [0, 2], [3, 1], [4, 2], [7, 1], [8, nan]]
# 목표 지점에 이르기까지 걸린 단계 수는 70단계입니다

# %%
# theta를 수정하는 함수

def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 학습률
    T = len(s_a_history) - 1  # 목표 지점에 이르기까지 걸린 단계 수

    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    delta_theta = theta.copy()  # Δtheta를 구할 준비, 포인터 참조이므로 delta_theta = theta로는 안됨

    # delta_theta를 요소 단위로 계산
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])):  # theta가 nan이 아닌 경우

                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 히스토리에서 상태 i인 것만 모아오는 리스트 컴프리헨션

                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 상태 i에서 행동 j를 취한 경우만 모음

                N_i = len(SA_i)  # 상태 i에서 모든 행동을 취한 횟수
                N_ij = len(SA_ij)  # 상태 i에서 행동 j를 취한 횟수 
                
                # 초판에서 부호 오류가 있었음(수정일 : 1807030
                #delta_theta[i, j] = (N_ij + pi[i, j] * N_i) / T
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T

    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49892857 0.50107143 0.        ]
#  [0.         0.49964286 0.         0.50035714]
#  [0.         0.         0.49964286 0.50035714]
#  [0.33349157 0.33396833 0.3325401  0.        ]
#  [0.         0.         0.49857143 0.50142857]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.50035714 0.49964286 0.         0.        ]]

# %%
# 정책 경사 알고리즘으로 미로 빠져나오기

stop_epsilon = 10**-4  # 정책의 변화가 10^-4 보다 작아지면 학습을 종료


theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:  # is_continue가 False가 될 때까지 반복
    s_a_history = goal_maze_ret_s_a(pi)  # 정책 π를 따라 미로를 탐색한 히스토리를 구함
    new_theta = update_theta(theta, pi, s_a_history)  # 파라미터 Θ를 수정
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 정책 π를 수정

    print(np.sum(np.abs(new_pi - pi)))  # 정책의 변화를 출력
    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
# Out:
# 0.007223438782645475
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.016521628704150193
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.014104701744712012
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.0067312893072483115
# 목표 지점에 이르기까지 걸린 단계 수는 92단계입니다
# 0.011792441138243681
# 목표 지점에 이르기까지 걸린 단계 수는 50단계입니다
# 0.03240308908625339
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.011467571393601383
# 목표 지점에 이르기까지 걸린 단계 수는 72단계입니다
# 0.007604117496560092
# 목표 지점에 이르기까지 걸린 단계 수는 76단계입니다
# 0.007084918709270083
# 목표 지점에 이르기까지 걸린 단계 수는 58단계입니다
# 0.018784012567563013
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.010839309953663612
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.004007571431966284
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.00755624962666851
# 목표 지점에 이르기까지 걸린 단계 수는 104단계입니다
# 0.015489060988239045
# 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.0115432814524562
# 목표 지점에 이르기까지 걸린 단계 수는 38단계입니다
# 0.01821881587971641
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.010983157621867301
# 목표 지점에 이르기까지 걸린 단계 수는 64단계입니다
# 0.009402369283160406
# 목표 지점에 이르기까지 걸린 단계 수는 42단계입니다
# 0.009302902439933647
# 목표 지점에 이르기까지 걸린 단계 수는 130단계입니다
# 0.020178025690240853
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.014737268129099923
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.01041031527018016
# 목표 지점에 이르기까지 걸린 단계 수는 112단계입니다
# 0.011231562042469279
# 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.012231243826243632
# 목표 지점에 이르기까지 걸린 단계 수는 50단계입니다
# 0.04794495961658585
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01024598943952948
# 목표 지점에 이르기까지 걸린 단계 수는 48단계입니다
# 0.015724423530938503
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.006256343681515675
# 목표 지점에 이르기까지 걸린 단계 수는 184단계입니다
# 0.012645080298571643
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.007532213698486445
# 목표 지점에 이르기까지 걸린 단계 수는 50단계입니다
# 0.016733490921860716
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.02358971112125441
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01089265177573967
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.008353564553435167
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.03045773472419744
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.009953843629440517
# 목표 지점에 이르기까지 걸린 단계 수는 82단계입니다
# 0.01403377927940952
# 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.021744515482604754
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.010887335352989691
# 목표 지점에 이르기까지 걸린 단계 수는 154단계입니다
# 0.014542806408792297
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.018901121186887915
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.010896535399058327
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.011574468357198109
# 목표 지점에 이르기까지 걸린 단계 수는 92단계입니다
# 0.017398153364101054
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.00858135724782666
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.022702959415890844
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02018211517241686
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.031102126131289265
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.007320013590259966
# 목표 지점에 이르기까지 걸린 단계 수는 210단계입니다
# 0.04658077382928566
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012882004515393342
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.013213525939655246
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.01601895906604006
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.010641705858667305
# 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.01312678395427841
# 목표 지점에 이르기까지 걸린 단계 수는 38단계입니다
# 0.015708518976300656
# 목표 지점에 이르기까지 걸린 단계 수는 46단계입니다
# 0.014882529576257963
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.014496145098457702
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.01953184890728088
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.01910721291482187
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.020979457631902898
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.025595517962186398
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011442846063353496
# 목표 지점에 이르기까지 걸린 단계 수는 62단계입니다
# 0.021333027281885464
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.020778221541032427
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.018076872541603894
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.005543063512048141
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.024905594401149367
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.019768825619999153
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.011328946386667205
# 목표 지점에 이르기까지 걸린 단계 수는 44단계입니다
# 0.013380011383830936
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.008944373936453198
# 목표 지점에 이르기까지 걸린 단계 수는 58단계입니다
# 0.012035031928589401
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.031130638068633865
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01898540132848553
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.04493606793250038
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01692669154769233
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.009850607518253729
# 목표 지점에 이르기까지 걸린 단계 수는 42단계입니다
# 0.007878194676762817
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.010887713124751397
# 목표 지점에 이르기까지 걸린 단계 수는 46단계입니다
# 0.013864931677480874
# 목표 지점에 이르기까지 걸린 단계 수는 38단계입니다
# 0.015580207813998992
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.027317777202104432
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.032640361022533926
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01997246512229578
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.044088317974440905
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010276676888046787
# 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.01760793528791893
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.025625588278539002
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.016630780445129167
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.025020465326883956
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01290672907981194
# 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.013758145614594541
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.03066987655716058
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013659073833836133
# 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.029668458397767772
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.011403185712005603
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.04307656665139681
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0184754205192163
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.014233436251615661
# 목표 지점에 이르기까지 걸린 단계 수는 48단계입니다
# 0.013635349036528077
# 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.019271849907161853
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.01404324760853315
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.019786078943213936
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.009495813687608212
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.02004431064864942
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.021154131541078314
# 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.021070040206472518
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.018965236801655294
# 목표 지점에 이르기까지 걸린 단계 수는 38단계입니다
# 0.013151949836706867
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.02191540419224669
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.02586991623325524
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.013945231932327662
# 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.009848135425864213
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.00964402542623316
# 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.013347399177471297
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.02106453416163967
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.025031756743335243
# 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.006904082468219275
# 목표 지점에 이르기까지 걸린 단계 수는 94단계입니다
# 0.026086604193290175
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.017691487192990074
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.008049532884180421
# 목표 지점에 이르기까지 걸린 단계 수는 66단계입니다
# 0.013445781551122249
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.008542879752068466
# 목표 지점에 이르기까지 걸린 단계 수는 86단계입니다
# 0.010683464009132226
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.013613663273865262
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.02244209986714829
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.031087077472242375
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.04121768501674611
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02011263105333344
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.00731482658185284
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.01337186635642601
# 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.028818782012117572
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01664034496160538
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.013697347105061264
# 목표 지점에 이르기까지 걸린 단계 수는 128단계입니다
# 0.028525199043530847
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017163221400341988
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.017259048843202396
# 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.01127370491070595
# 목표 지점에 이르기까지 걸린 단계 수는 120단계입니다
# 0.009449865630096255
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.040206299329744344
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012714167700658252
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.02807794955505155
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.03045313167772082
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.03913098013789959
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02078693832241904
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.022461599226634904
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.015468746235561215
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.008149734543215215
# 목표 지점에 이르기까지 걸린 단계 수는 56단계입니다
# 0.038385812619906534
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021431040374551097
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.013322126508733628
# 목표 지점에 이르기까지 걸린 단계 수는 42단계입니다
# 0.011396768819870368
# 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.014952804157066485
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.009108980105127396
# 목표 지점에 이르기까지 걸린 단계 수는 70단계입니다
# 0.006196083910806893
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.018097321278365303
# 목표 지점에 이르기까지 걸린 단계 수는 46단계입니다
# 0.01686095931874429
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.038023756812735954
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.032021498779012586
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.019603553696703413
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.03132688467475839
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02142212829048068
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.03018093462394708
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01758025458748319
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.031040658127312715
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.011797258920085124
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.01602221326668976
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.012708051968520845
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.036429815641429525
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02380795515791012
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.035879737496089775
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.030913290507685043
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02136106044808536
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01731891802908364
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.02222936680460566
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.02193885904302728
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.028366422846836714
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.01088000585686652
# 목표 지점에 이르기까지 걸린 단계 수는 76단계입니다
# 0.015031529887339579
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.031136986196895394
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.03543529597292308
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014106518385463257
# 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.01573699842827686
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.029050014753267017
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.013357243456909557
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.010646232974116265
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.02150388321901578
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.01771541201994975
# 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.03487025173789793
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02177128232806308
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.021774085408461596
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.012190014992072506
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01666584825530759
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.030556418636547372
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.034209777607732
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015472741822704666
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.033638242794370526
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010838778510986108
# 목표 지점에 이르기까지 걸린 단계 수는 58단계입니다
# 0.02972363108370671
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.022152301902288923
# 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.02004673767880294
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.012695106005316786
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.02442641871983109
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010403287869129835
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.03296258392067655
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02460093526055296
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.03214037666574962
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016908867609616296
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.02593642597513629
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.012890564631053425
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.013743252738050965
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.015435920977411893
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.015057523299413234
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.031693304320411037
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019085957447749324
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.022912137995110937
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.02592028258032339
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.016169517541774397
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.007167204840559965
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.031108526522760194
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02655711194509297
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.012425649511938197
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.019883362765871132
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.017704100954805263
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.03054609726355484
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.020179956139530775
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.018485353510903912
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010649148287258547
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.029182305837851558
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.015993084782383815
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01881466962014991
# 목표 지점에 이르기까지 걸린 단계 수는 64단계입니다
# 0.014474158259894898
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.014816999496251482
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01943871845846451
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01942459380213707
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02972824962979001
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.029285696527199645
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022530455958114953
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.028225521024544592
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.012724860707669539
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.028570576081421273
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02144687843378057
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.019976332482677467
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.025788158276530554
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010832669857367555
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.01518067981875909
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.021832974202795397
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015256161453854139
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.027477064670600126
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016565655359022075
# 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.016965109408778878
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01680941932352581
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.018485688962505353
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.021182579258413964
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02548684967761189
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010160225912080462
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.021562891044947408
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.019654992381416575
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.022941956556735088
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013766839130787495
# 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.017270192468904155
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.026656107286344682
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.026257669791339505
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02586519563181075
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02547866836036694
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019413724461333742
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.019952773706331445
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01851729193012039
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014896356603667532
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.024435287239539444
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.024818208224299726
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015703966572788053
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.012136285749858255
# 목표 지점에 이르기까지 걸린 단계 수는 48단계입니다
# 0.016740464101112823
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.013296827548474388
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01767126862586485
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.03182254212695587
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.019336633071534465
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.012168095813599955
# 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.018122643058189336
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.014623390987288848
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.024659003638969168
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015442057058407205
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02591289626945195
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.016030562413995003
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017636599433870304
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01150607242291607
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.023437560598860263
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01614906986353215
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.023943110345242935
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022937917355831144
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.023443683537573756
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.023091625540123034
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022745450513497106
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.017097459651276847
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011955772054631275
# 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.020078981947185576
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015732941561341224
# 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.012310100189835915
# 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.02252809489359192
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.024208722549747153
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.02706130828061018
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.010459186876211585
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.022232781616449315
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01040755840671062
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.015093104008705255
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017506624046333408
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01890922867730979
# 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.025063612640734312
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02189905874316081
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021574708892262373
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019417904524894114
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.016942409059266
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.022910879824929536
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.024237739912340933
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011711478739388659
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.019698323829754283
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.021266740445643167
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0192980110109727
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.020856236936478895
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01300089704091223
# 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0
    # 프레임 단위로 이미지 생성
    state = s_a_history[i][0]  # 현재 위치
    x = (state % 3) + 0.5  # 상태의 x좌표 : 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3)  # y좌표 : 2.5에서 3으로 나눈 몫을 뺌
    line.set_data(x, y)
    return (line,)


#　초기화 함수와 프레임 단위 이미지 생성한수를 사용하여 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgeb204c29e71c45c4a868941de6efeb10">
#     <br>
#     <input id="_anim_slidereb204c29e71c45c4a868941de6efeb10" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animeb204c29e71c45c4a868941de6efeb10.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animeb204c29e71c45c4a868941de6efeb10.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecteb204c29e71c45c4a868941de6efeb10" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgeb204c29e71c45c4a868941de6efeb10";
#     var slider_id = "_anim_slidereb204c29e71c45c4a868941de6efeb10";
#     var loop_select_id = "_anim_loop_selecteb204c29e71c45c4a868941de6efeb10";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAHJpJREFUeJzt3XtwVPX9//HXJruBJJsUfoCYiyYo\
# lRh+IpLAEGilEpRYh1pFcBIvQCxqpdavxME6pXjpz46NRgYrP0fmC1G8KygGp1pSwDCAFcJF/HJR\
# +dYIBCyQgpB7lv18/1jCl0sgCSQ5n919PmYyDtlL3vsxeebk5OQclzHGCABgnQinBwAAtIxAA4Cl\
# CDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQA\
