# %% [markdown]
# ## 3.4 Q러닝 구현

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 애니메이션을 만드는 함수
# 참고 URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole.mp4')  # 애니메이션을 저장하는 부분
    display(display_animation(anim, default_mode='loop'))

# %%
# 상수 정의
ENV = 'CartPole-v0'  # 태스크 이름
NUM_DIZITIZED = 6  # 각 상태를 이산변수로 변환할 구간 수
GAMMA = 0.99  # 시간할인율
ETA = 0.5  # 학습률
MAX_STEPS = 200  # 1에피소드 당 최대 단계 수
NUM_EPISODES = 1000  # 최대 에피소드 수

# %%
class Agent:
    '''CartPole 에이전트 역할을 할 클래스, 봉 달린 수레이다'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # 에이전트가 행동을 결정하는 두뇌 역할

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q함수 수정'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''행동 결정'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''에이전트의 두뇌 역할을 하는 클래스, Q러닝을 실제 수행'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # 행동의 가짓수(왼쪽, 오른쪽)를 구함

        # Q테이블을 생성. 줄 수는 상태를 구간수^4(4는 변수의 수)가지 값 중 하나로 변환한 값, 열 수는 행동의 가짓수
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))


    def bins(self, clip_min, clip_max, num):
        '''관측된 상태(연속값)를 이산변수로 변환하는 구간을 계산'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''관측된 상태 observation을 이산변수로 변환'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''Q러닝으로 Q테이블을 수정'''
        state = self.digitize_state(observation)  # 상태를 이산변수로 변환
        state_next = self.digitize_state(observation_next)  # 다음 상태를 이산변수로 변환
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        '''ε-greedy 알고리즘을 적용하여 서서히 최적행동의 비중을 늘림'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 0,1 두 가지 행동 중 하나를 무작위로 선택
        return action

# %%
class Environment:
    '''CartPole을 실행하는 환경 역할을 하는 클래스'''

    def __init__(self):
        self.env = gym.make(ENV)  # 실행할 태스크를 설정
        num_states = self.env.observation_space.shape[0]  # 태스크의 상태 변수 수를 구함
        num_actions = self.env.action_space.n  # 가능한 행동 수를 구함
        self.agent = Agent(num_states, num_actions)  # 에이전트 객체를 생성

    def run(self):
        '''실행'''
        complete_episodes = 0  # 성공한(195단계 이상 버틴) 에피소드 수
        is_episode_final = False  # 마지막 에피소드 여부
        frames = []  # 애니메이션을 만드는데 사용할 이미지를 저장하는 변수

        for episode in range(NUM_EPISODES):  # 에피소드 수 만큼 반복
            observation = self.env.reset()  # 환경 초기화

            for step in range(MAX_STEPS):  # 1 에피소드에 해당하는 반복

                if is_episode_final is True:  # 마지막 에피소드이면 frames에 각 단계의 이미지를 저장
                    frames.append(self.env.render(mode='rgb_array'))

                # 행동을 선택
                action = self.agent.get_action(observation, episode)

                # 행동 a_t를 실행하여 s_{t+1}, r_{t+1}을 계산
                observation_next, _, done, _ = self.env.step(
                    action)  # reward, info는 사용하지 않으므로 _로 처리함

                # 보상을 부여
                if done:  # 200단계를 넘어서거나 일정 각도 이상 기울면 done의 값이 True가 됨
                    if step < 195:
                        reward = -1  # 봉이 쓰러지면 페널티로 보상 -1 부여
                        complete_episodes = 0  # 195단계 이상 버티면 해당 에피소드를 성공 처리
                    else:
                        reward = 1  # 쓰러지지 않고 에피소드를 끝내면 보상 1 부여
                        complete_episodes += 1  # 에피소드 연속 성공 기록을 업데이트
                else:
                    reward = 0  # 에피소드 중에는 보상이 0

                # 다음 단계의 상태 observation_next로 Q함수를 수정
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)

                # 다음 단계 상태 관측
                observation = observation_next

                # 에피소드 마무리
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(
                        episode, step + 1))
                    break

            if is_episode_final is True:  # 마지막 에피소드에서는 애니메이션을 만들고 저장
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:  # 10 에피소드 연속으로 성공한 경우
                print('10 에피소드 연속 성공')
                is_episode_final = True  # 다음 에피소드가 마지막 에피소드가 됨

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# /home/taeho/anaconda3/envs/pytorch/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# 0 Episode: Finished after 14 time steps
# 1 Episode: Finished after 11 time steps
# 2 Episode: Finished after 8 time steps
# 3 Episode: Finished after 11 time steps
# 4 Episode: Finished after 11 time steps
# 5 Episode: Finished after 14 time steps
# 6 Episode: Finished after 30 time steps
# 7 Episode: Finished after 17 time steps
# 8 Episode: Finished after 12 time steps
# 9 Episode: Finished after 10 time steps
# 10 Episode: Finished after 11 time steps
# 11 Episode: Finished after 16 time steps
# 12 Episode: Finished after 10 time steps
# 13 Episode: Finished after 9 time steps
# 14 Episode: Finished after 15 time steps
# 15 Episode: Finished after 17 time steps
# 16 Episode: Finished after 20 time steps
# 17 Episode: Finished after 11 time steps
# 18 Episode: Finished after 20 time steps
# 19 Episode: Finished after 19 time steps
# 20 Episode: Finished after 9 time steps
# 21 Episode: Finished after 43 time steps
# 22 Episode: Finished after 57 time steps
# 23 Episode: Finished after 71 time steps
# 24 Episode: Finished after 21 time steps
# 25 Episode: Finished after 63 time steps
# 26 Episode: Finished after 132 time steps
# 27 Episode: Finished after 63 time steps
# 28 Episode: Finished after 135 time steps
# 29 Episode: Finished after 45 time steps
# 30 Episode: Finished after 37 time steps
# 31 Episode: Finished after 30 time steps
# 32 Episode: Finished after 35 time steps
# 33 Episode: Finished after 47 time steps
# 34 Episode: Finished after 18 time steps
# 35 Episode: Finished after 86 time steps
# 36 Episode: Finished after 26 time steps
# 37 Episode: Finished after 35 time steps
# 38 Episode: Finished after 10 time steps
# 39 Episode: Finished after 20 time steps
# 40 Episode: Finished after 25 time steps
# 41 Episode: Finished after 116 time steps
# 42 Episode: Finished after 34 time steps
# 43 Episode: Finished after 42 time steps
# 44 Episode: Finished after 29 time steps
# 45 Episode: Finished after 94 time steps
# 46 Episode: Finished after 10 time steps
# 47 Episode: Finished after 24 time steps
# 48 Episode: Finished after 8 time steps
# 49 Episode: Finished after 22 time steps
# 50 Episode: Finished after 52 time steps
# 51 Episode: Finished after 19 time steps
# 52 Episode: Finished after 120 time steps
# 53 Episode: Finished after 52 time steps
# 54 Episode: Finished after 57 time steps
# 55 Episode: Finished after 90 time steps
# 56 Episode: Finished after 77 time steps
# 57 Episode: Finished after 15 time steps
# 58 Episode: Finished after 21 time steps
# 59 Episode: Finished after 12 time steps
# 60 Episode: Finished after 15 time steps
# 61 Episode: Finished after 29 time steps
# 62 Episode: Finished after 70 time steps
# 63 Episode: Finished after 127 time steps
# 64 Episode: Finished after 54 time steps
# 65 Episode: Finished after 187 time steps
# 66 Episode: Finished after 73 time steps
# 67 Episode: Finished after 197 time steps
# 68 Episode: Finished after 94 time steps
# 69 Episode: Finished after 96 time steps
# 70 Episode: Finished after 200 time steps
# 71 Episode: Finished after 136 time steps
# 72 Episode: Finished after 19 time steps
# 73 Episode: Finished after 70 time steps
# 74 Episode: Finished after 141 time steps
# 75 Episode: Finished after 200 time steps
# 76 Episode: Finished after 58 time steps
# 77 Episode: Finished after 71 time steps
# 78 Episode: Finished after 84 time steps
# 79 Episode: Finished after 57 time steps
# 80 Episode: Finished after 31 time steps
# 81 Episode: Finished after 82 time steps
# 82 Episode: Finished after 89 time steps
# 83 Episode: Finished after 50 time steps
# 84 Episode: Finished after 9 time steps
# 85 Episode: Finished after 42 time steps
# 86 Episode: Finished after 37 time steps
# 87 Episode: Finished after 152 time steps
# 88 Episode: Finished after 137 time steps
# 89 Episode: Finished after 119 time steps
# 90 Episode: Finished after 72 time steps
# 91 Episode: Finished after 91 time steps
# 92 Episode: Finished after 200 time steps
# 93 Episode: Finished after 184 time steps
# 94 Episode: Finished after 132 time steps
# 95 Episode: Finished after 39 time steps
# 96 Episode: Finished after 10 time steps
# 97 Episode: Finished after 26 time steps
# 98 Episode: Finished after 49 time steps
# 99 Episode: Finished after 31 time steps
# 100 Episode: Finished after 90 time steps
# 101 Episode: Finished after 41 time steps
# 102 Episode: Finished after 36 time steps
# 103 Episode: Finished after 89 time steps
# 104 Episode: Finished after 183 time steps
# 105 Episode: Finished after 151 time steps
# 106 Episode: Finished after 93 time steps
# 107 Episode: Finished after 134 time steps
# 108 Episode: Finished after 97 time steps
# 109 Episode: Finished after 134 time steps
# 110 Episode: Finished after 200 time steps
# 111 Episode: Finished after 200 time steps
# 112 Episode: Finished after 153 time steps
# 113 Episode: Finished after 200 time steps
# 114 Episode: Finished after 154 time steps
# 115 Episode: Finished after 145 time steps
# 116 Episode: Finished after 99 time steps
# 117 Episode: Finished after 157 time steps
# 118 Episode: Finished after 79 time steps
# 119 Episode: Finished after 62 time steps
# 120 Episode: Finished after 87 time steps
# 121 Episode: Finished after 53 time steps
# 122 Episode: Finished after 81 time steps
# 123 Episode: Finished after 200 time steps
# 124 Episode: Finished after 25 time steps
# 125 Episode: Finished after 167 time steps
# 126 Episode: Finished after 88 time steps
# 127 Episode: Finished after 33 time steps
# 128 Episode: Finished after 62 time steps
# 129 Episode: Finished after 173 time steps
# 130 Episode: Finished after 18 time steps
# 131 Episode: Finished after 32 time steps
# 132 Episode: Finished after 56 time steps
# 133 Episode: Finished after 110 time steps
# 134 Episode: Finished after 58 time steps
# 135 Episode: Finished after 120 time steps
# 136 Episode: Finished after 58 time steps
# 137 Episode: Finished after 168 time steps
# 138 Episode: Finished after 63 time steps
# 139 Episode: Finished after 156 time steps
# 140 Episode: Finished after 181 time steps
# 141 Episode: Finished after 200 time steps
# 142 Episode: Finished after 56 time steps
# 143 Episode: Finished after 171 time steps
# 144 Episode: Finished after 75 time steps
# 145 Episode: Finished after 200 time steps
# 146 Episode: Finished after 172 time steps
# 147 Episode: Finished after 14 time steps
# 148 Episode: Finished after 168 time steps
# 149 Episode: Finished after 149 time steps
# 150 Episode: Finished after 123 time steps
# 151 Episode: Finished after 170 time steps
# 152 Episode: Finished after 200 time steps
# 153 Episode: Finished after 145 time steps
# 154 Episode: Finished after 147 time steps
# 155 Episode: Finished after 158 time steps
# 156 Episode: Finished after 200 time steps
# 157 Episode: Finished after 180 time steps
# 158 Episode: Finished after 200 time steps
# 159 Episode: Finished after 76 time steps
# 160 Episode: Finished after 174 time steps
# 161 Episode: Finished after 200 time steps
# 162 Episode: Finished after 175 time steps
# 163 Episode: Finished after 146 time steps
# 164 Episode: Finished after 114 time steps
# 165 Episode: Finished after 95 time steps
# 166 Episode: Finished after 148 time steps
# 167 Episode: Finished after 66 time steps
# 168 Episode: Finished after 176 time steps
# 169 Episode: Finished after 195 time steps
# 170 Episode: Finished after 99 time steps
# 171 Episode: Finished after 57 time steps
# 172 Episode: Finished after 93 time steps
# 173 Episode: Finished after 37 time steps
# 174 Episode: Finished after 53 time steps
# 175 Episode: Finished after 12 time steps
# 176 Episode: Finished after 90 time steps
# 177 Episode: Finished after 111 time steps
# 178 Episode: Finished after 33 time steps
# 179 Episode: Finished after 15 time steps
# 180 Episode: Finished after 43 time steps
# 181 Episode: Finished after 140 time steps
# 182 Episode: Finished after 85 time steps
# 183 Episode: Finished after 169 time steps
# 184 Episode: Finished after 154 time steps
# 185 Episode: Finished after 79 time steps
# 186 Episode: Finished after 200 time steps
# 187 Episode: Finished after 200 time steps
# 188 Episode: Finished after 200 time steps
# 189 Episode: Finished after 200 time steps
# 190 Episode: Finished after 200 time steps
# 191 Episode: Finished after 200 time steps
# 192 Episode: Finished after 200 time steps
# 193 Episode: Finished after 200 time steps
# 194 Episode: Finished after 200 time steps
# 195 Episode: Finished after 200 time steps
# 10 에피소드 연속 성공
# 196 Episode: Finished after 200 time steps
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgTPHKSFDOQFIVNXWY">
#     <br>
#     <input id="_anim_sliderTPHKSFDOQFIVNXWY" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animTPHKSFDOQFIVNXWY.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animTPHKSFDOQFIVNXWY.slower()">&#8211;</button>
#     <button onclick="animTPHKSFDOQFIVNXWY.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTPHKSFDOQFIVNXWY.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectTPHKSFDOQFIVNXWY" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgTPHKSFDOQFIVNXWY";
#     var slider_id = "_anim_sliderTPHKSFDOQFIVNXWY";
#     var loop_select_id = "_anim_loop_selectTPHKSFDOQFIVNXWY";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
